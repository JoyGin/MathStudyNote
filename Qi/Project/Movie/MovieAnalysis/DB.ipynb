# %%
import pandas as pd

# %%
import numpy as np

# %%
df1 = pd.read_csv("data/dbTop.csv",encoding='utf-8')

# %%
df1
# Out:
#      Unnamed: 0  comment_num  movie_index  movie_name  movie_score
# 0             0      2075220            1      肖申克的救赎          9.7
# 1             1      1538456            2        霸王别姬          9.6
# 2             2      1568300            3        阿甘正传          9.5
# 3             3      1759176            4     这个杀手不太冷          9.4
# 4             4       983201            5        美丽人生          9.5
# ..          ...          ...          ...         ...          ...
# 245         245       213026          246        黑鹰坠落          8.7
# 246         246       120761          247        四个春天          8.9
# 247         247       387807          248        网络谜踪          8.6
# 248         248       283699          249         发条橙          8.6
# 249         249       261449          250  黑客帝国2：重装上阵          8.6
#
# [250 rows x 5 columns]

# %%
C= df1['movie_score'].mean()

# %%
m = df1['comment_num'].mean()

# %%
q_movies = df1.copy().loc[df1['comment_num'] >= m]

# %%
def weighted_rating(x, m=m, C=C):
    v = x['comment_num']
    R = x['movie_score']
    # Calculation based on the IMDB formula
    return (v/(v+m) * R) + (m/(m+v) * C)

# %%
q_movies['score'] = q_movies.apply(weighted_rating, axis=1)

# %%
#Sort movies based on score calculated above
q_movies = q_movies.sort_values('score', ascending=False)

#Print the top 15 movies
q_movies[['comment_num','movie_name', 'score']].head(50)
# Out:
#     comment_num movie_name     score
# 0       2075220     肖申克的救赎  9.536969
# 1       1538456       霸王别姬  9.419758
# 2       1568300       阿甘正传  9.347258
# 4        983201       美丽人生  9.287833
# 3       1759176    这个杀手不太冷  9.282885
# 6       1629882       千与千寻  9.275844
# 5       1521386      泰坦尼克号  9.269247
# 7        799056     辛德勒的名单  9.258229
# 9       1042417    忠犬八公的故事  9.229181
# 8       1497893       盗梦空间  9.193520
# 10      1249363      海上钢琴师  9.178569
# 15      1122065       星际穿越  9.169159
# 11      1121679      楚门的世界  9.169129
# 13       985791     机器人总动员  9.157324
# 14       967402     放牛班的春天  9.155561
# 21       678927         教父  9.120827
# 17       678018         熔炉  9.120691
# 12      1390290    三傻大闹宝莱坞  9.114771
# 18      1315560      疯狂动物城  9.111303
# 16      1099660  大话西游之大圣娶亲  9.099484
# 20       929470         龙猫  9.087688
# 19       897740        无间道  9.085175
# 26       748635   蝙蝠侠：黑暗骑士  9.071687
# 24       725713       触不可及  9.069327
# 27       582658         活着  9.052385
# 32       551077  指环王3：王者无敌  9.048035
# 30       532185       末代皇帝  9.045308
# 23      1296188       怦然心动  9.039015
# 22      1110837     当幸福来敲门  9.032087
# 28      1096652      寻梦环游记  9.031491
# 34      1041651   少年派的奇幻漂流  9.029080
# 40       713120    哈尔的移动城堡  9.010195
# 33       677156       何以为家  9.007499
# 44       621783      闻香识女人  9.003016
# 39       618466       天空之城  9.002733
# 47      1523873      我不是药神  8.971273
# 31      1140268     摔跤吧！爸爸  8.964639
# 35       974994      飞屋环游记  8.960731
# 41       880056  大话西游之月光宝盒  8.958070
# 43       713862       罗马假日  8.952425
# 45       684439  哈利·波特与魔法石  8.951264
# 48       640113      搏击俱乐部  8.949403
# 55       588574       猫鼠游戏  8.947052
# 51       585866        狮子王  8.946922
# 61       567699       黑客帝国  8.946036
# 56       565607  指环王1：魔戒再现  8.945932
# 59       550314       美丽心灵  8.945160
# 68      1105068        绿皮书  8.895901
# 64       769540      V字仇杀队  8.894834
# 63       718610   本杰明·巴顿奇事  8.894622

# %%
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-126-fb471395891c> in <module>
# ----> 1 q_movies.head(50).to_csv('data/mytop.csv',encoding='utf_8_sig')
#
# D:\anaconda\envs\Python3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3202             decimal=decimal,
#    3203         )
# -> 3204         formatter.save()
#    3205
#    3206         if path_or_buf is None:
#
# D:\anaconda\envs\Python3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     186                 self.mode,
#     187                 encoding=self.encoding,
# --> 188                 compression=dict(self.compression_args, method=self.compression),
#     189             )
#     190             close = True
#
# D:\anaconda\envs\Python3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     426         if encoding:
#     427             # Encoding
# --> 428             f = open(path_or_buf, mode, encoding=encoding, newline="")
#     429         elif is_text:
#     430             # No explicit encoding
#
# PermissionError: [Errno 13] Permission denied: 'data/mytop.csv'
